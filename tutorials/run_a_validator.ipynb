# %%
import commune as c

# %%
vali = c.module('vali')

c.print(vali.config(to_munch=False))
# Out:
# {
#     'key': None,
#     'network': 'subspace',
#     'sleep': 0.1,
#     'load': False,
#     'stats': {},
#     'max_stats_history': 100,
#     'save_interval': 1000,
#     'vote_interval': 1000,
#     'alpha': 0.9,
#     'timeout': 1,
#     'tag': 'base',
#     'run': True,
#     'num_threads': 0,
#     'module_prefix': 'model.openai',
#     'parallel_jobs': 10,
#     'start': False
# }

# %%
v = vali()

# %%
vali_code = v.code()
c.print(vali_code)
# Out:
# # import nest_asyncio
# # nest_asyncio.apply()
# import commune as c
#
# import threading
#
#
# class Validator(c.Module):
#
#     def __init__(self, config=None,  **kwargs):
#         self.set_config(config=config, kwargs=kwargs)
#
#         self.set_subspace( )
#         self.stats = {}
#         self.start_time = c.time()
#         self.count = 0
#         self.threads = []
#
#         if self.config.start:
#             self.start()
#
#     def start(self):
#         # start threads, ensure they are daemons, and dont vote
#         for t in range(self.config.num_threads):
#             t = threading.Thread(target=self.run, kwargs={'vote':False})
#             t.daemon = True
#             t.start()
#             self.threads.append(t)
#
#         # main thread
#         self.run(vote=True)
#
#     def set_subspace(self):
#         self.subspace = c.module(self.config.network)()
#         self.modules = self.subspace.modules()
# ...

# %%
c.servers()
# Out:
# ['module', 'model.openai', 'model.openai::whadup']
