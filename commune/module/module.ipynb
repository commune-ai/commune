# %%
import commune as c

# %%
# list all of the modules
c.modules()[:10]
# Out:
# ['demo_c',
#  'api',
#  'test',
#  'module.test',
#  'module',
#  'websocket',
#  'demo',
#  'pipeline',
#  'crypto.hash',
#  'crypto.key.aes']

# %%
# to search for a specific module, use the search function
for k in ['model.llama', 'data', 'demo', 'hf']:
    c.print('Searching for ', k)
    c.print( c.modules(k))
# Out:
# Searching for  model.llama
# ['model.llama']
# Searching for  data
# [
#     'finetune.data',
#     'bittensor.neurons.text.prompting.miners.self_hosted.coati.dataset',
#     'data',
#     'data.image.globe',
#     'data.hf',
#     'data.text.squad',
#     'data.text.folder',
#     'data.text.pile',
#     'data.text.code',
#     'data.text.bittensor',
#     'data.text.bt.pile',
#     'data.text.bt.prompt',
#     'data.text.realfake',
#     'data.text.truthqa'
# ]
# Searching for  demo
# ['demo_c', 'demo']
# Searching for  hf
# ['hf', 'model.hf', 'data.hf']

# %% [markdown]
# ## Lets get a Module

# %%
demo = c.module('demo')

c.print('## Code for demo module')
c.print(demo.code())
# Out:
# import commune as c
#
# class Demo(c.Module):
#     def __init__(self, config = None, **kwargs):
#         self.set_config(config, kwargs=kwargs)
#     def bro(self, x='fam'):
#         return f'whadup {x}'
#
#     def hey(self, x='fam'):
#         return f'whadup {x}'
#     @classmethod
#     def test(cls, **kwargs):
#         self = cls(**kwargs)
#         print('Testing demo')
#         c.print(self.config)
#         print(self.bro())
#         print(self.hey())
#         assert self.bro() == 'whadup fam'
#         assert self.hey() == 'whadup fam'
#         return True

# %%
c.
